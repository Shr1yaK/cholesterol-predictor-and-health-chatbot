# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
df=pd.read_csv('../datasets/base_data.csv')
df
# Out:
#       AGE  SYS BP  DIA BP  HEART RATE  TOTAL CHOLESTROL
# 0      64   148.0    85.0          90               221
# 1      36   168.0    98.0          72               212
# 2      46   116.0    71.0          88               250
# 3      50   158.0    88.0          68               233
# 4      64   136.5    85.0          70               241
# ...   ...     ...     ...         ...               ...
# 3385   60   123.5    79.0          70               261
# 3386   46   102.0    56.0          80               199
# 3387   44   164.0   119.0          73               352
# 3388   60   167.0   105.0          80               191
# 3389   54   124.0    77.0          79               288
#
# [3390 rows x 5 columns]

# %%
df.shape
# Out:
# (3390, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AGE               3390 non-null   int64
#  1   SYS BP            3390 non-null   float64
#  2   DIA BP            3390 non-null   float64
#  3   HEART RATE        3390 non-null   int64
#  4   TOTAL CHOLESTROL  3390 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 132.6 KB

# %%
df.describe().round(2).T
# Out:
#                    count    mean    std    min    25%    50%    75%    max
# AGE               3390.0   49.54   8.59   32.0   42.0   49.0   56.0   70.0
# SYS BP            3390.0  132.60  22.29   83.5  117.0  128.5  144.0  295.0
# DIA BP            3390.0   82.88  12.02   48.0   74.5   82.0   90.0  142.5
# HEART RATE        3390.0   75.98  11.98   45.0   68.0   75.0   83.0  143.0
# TOTAL CHOLESTROL  3390.0  237.22  45.01  107.0  206.0  235.0  264.0  696.0

# %%
df_num=df.select_dtypes(include=['int64','float64'])
df_num
# Out:
#       AGE  SYS BP  DIA BP  HEART RATE  TOTAL CHOLESTROL
# 0      64   148.0    85.0          90               221
# 1      36   168.0    98.0          72               212
# 2      46   116.0    71.0          88               250
# 3      50   158.0    88.0          68               233
# 4      64   136.5    85.0          70               241
# ...   ...     ...     ...         ...               ...
# 3385   60   123.5    79.0          70               261
# 3386   46   102.0    56.0          80               199
# 3387   44   164.0   119.0          73               352
# 3388   60   167.0   105.0          80               191
# 3389   54   124.0    77.0          79               288
#
# [3390 rows x 5 columns]

# %%
ax=sns.pairplot(df_num, y_vars='AGE', x_vars='TOTAL CHOLESTROL')
ax.fig.suptitle("Variation of CHOLESTROL with AGE", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ax=sns.pairplot(df_num, y_vars='TOTAL CHOLESTROL', x_vars='AGE')
ax.fig.suptitle("Variation of CHOLESTROL with AGE", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ax=sns.pairplot(df_num, y_vars='TOTAL CHOLESTROL', x_vars='HEART RATE')
ax.fig.suptitle("Cholestrol vs Heart Rate", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ax=sns.pairplot(df_num, y_vars='HEART RATE', x_vars='TOTAL CHOLESTROL')
ax.fig.suptitle("Cholestrol vs Heart Rate", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ax=sns.pairplot(df_num, y_vars='SYS BP', x_vars='TOTAL CHOLESTROL')
ax.fig.suptitle("Cholestrol vs SYS BP", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ax=sns.pairplot(df_num, y_vars='DIA BP', x_vars='TOTAL CHOLESTROL')
ax.fig.suptitle("Cholestrol vs DIA BP", fontsize=20, y=1.2)
ax
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_num.hist(figsize=(10,14), bins= 30, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'HEART RATE'}>],
#        [<Axes: title={'center': 'TOTAL CHOLESTROL'}>, <Axes: >]],
#       dtype=object)

# %%
df_obj = df.select_dtypes(include = ['object'])
df
# Out:
#       AGE  SYS BP  DIA BP  HEART RATE  TOTAL CHOLESTROL
# 0      64   148.0    85.0          90               221
# 1      36   168.0    98.0          72               212
# 2      46   116.0    71.0          88               250
# 3      50   158.0    88.0          68               233
# 4      64   136.5    85.0          70               241
# ...   ...     ...     ...         ...               ...
# 3385   60   123.5    79.0          70               261
# 3386   46   102.0    56.0          80               199
# 3387   44   164.0   119.0          73               352
# 3388   60   167.0   105.0          80               191
# 3389   54   124.0    77.0          79               288
#
# [3390 rows x 5 columns]
